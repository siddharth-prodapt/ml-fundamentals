# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv('.env')
# Out:
# True

# %%
langchain_key = os.environ['LANGCHAIN_API_KEY']
openai_key = os.environ["OPENAI_API_KEY"]

# %%
langchain_key
# Out:
# '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'

# %%
openai_key
# Out:
# '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'

# %%
from langchain_openai import ChatOpenAI

# %%
# model = ChatOpenAI(model='gpt-3.5-turbo', api_key=openai_key)
llm = ChatOpenAI(model='gpt-3.5-turbo', api_key= openai_key)

# %%
llm.invoke('What is the color of apple?')
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~\Desktop\Learn2Live\data science\data analytics\.venv\Lib\site-packages\httpx\_transports\default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File ~\Desktop\Learn2Live\data science\data analytics\.venv\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File ~\Desktop\Learn2Live\data science\data analytics\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
# ...

# %% [markdown]
# Main Components of Langchain Framework
# 1. Models - Chat Models or Text Models
# 2. Prompts - Input Query given to user
# 3. Memory - Keeps the state of the chat
